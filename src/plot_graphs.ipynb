# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

import seaborn as sns

# %%
loop = 1000
qn = 300
filename = f"C:/Users/Admin/Desktop/ELO_Rating/Elo-Simulation/src/data/Actual Results C {loop}loop {qn}qn.csv"
df = pd.read_csv(filename)

# %%
df
# Out:
#            0.200        0.300        0.400        0.500        0.600  \
# 0     908.806399   968.995239   954.605964  1004.871957  1032.310530
# 1     940.582986   976.893941   980.678455  1009.325714  1051.176983
# 2     942.240470   977.738763   992.069781  1020.554244  1069.286809
# 3     943.425230   979.852003   995.135930  1022.272205  1070.719576
# 4     947.261801   980.739851   996.536961  1023.091378  1073.763553
# ..           ...          ...          ...          ...          ...
# 995  1234.941744  1249.740709  1310.735922  1392.475627  1449.899501
# 996  1234.952973  1255.394152  1312.714403  1400.142837  1451.045169
# 997  1257.645118  1293.224533  1322.028762  1405.773662  1454.950669
# 998  1263.270893  1300.445421  1326.394275  1431.309631  1467.026133
# 999  1266.363115  1319.966578  1359.407320  1441.987475  1475.498470
#
#            0.700        0.800        0.900        0.950        0.990  \
# 0    1099.431220  1163.605602  1324.440931  1389.709037  1594.078804
# 1    1103.250164  1169.076119  1336.944179  1410.234494  1613.907430
# 2    1122.475503  1175.289557  1337.871478  1417.711225  1633.680057
# 3    1126.734559  1187.184163  1340.975433  1426.153810  1650.353588
# 4    1136.812641  1196.203152  1344.536004  1438.616955  1659.959043
# ..           ...          ...          ...          ...          ...
# 995  1540.537931  1699.106960  1813.795713  1839.593377  1847.329454
# 996  1545.852101  1706.028096  1814.951771  1842.084158  1847.806974
# 997  1558.340913  1743.786891  1818.695596  1853.495149  1852.656158
# 998  1593.436845  1745.863123  1819.569732  1856.974315  1855.096698
# 999  1629.824154  1792.242512  1827.893445  1859.929538  1864.115452
#
#            1.000
# 0    1800.000000
# 1    1800.000000
# 2    1800.000000
# 3    1800.000000
# 4    1800.000000
# ..           ...
# 995  1848.945646
# 996  1849.735039
# 997  1850.740986
# 998  1850.880660
# 999  1855.656911
#
# [1000 rows x 11 columns]

# %%
acc03 = df["0.300"]
acc03
# Out:
# 0       968.995239
# 1       976.893941
# 2       977.738763
# 3       979.852003
# 4       980.739851
#           ...
# 995    1249.740709
# 996    1255.394152
# 997    1293.224533
# 998    1300.445421
# 999    1319.966578
# Name: 0.300, Length: 1000, dtype: float64

# %%
item = "0.200"
sns.displot(df[item], kde=True, color = "tab:blue", bins=30, alpha=0.2)
person_mean = np.mean(df[item])
plt.xlabel("Elo Rating")
plt.ylabel("Density")
plt.axvline(x=person_mean, color='black', linestyle='--', linewidth=2)
plt.text(person_mean + 30,60, f"mean = {round(person_mean)}", color='black', weight="bold")
plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")
# Out:
# Text(0.5, 1.0, 'Elo Rating Distribution for C with accuracy = 0.200 (Nloop = 1000, NQn = 300)')

# %%
def show_pdf_normal(item):
    person = df[item]
    person_mean = np.mean(person)
    person_std = np.std(person)
    pdf = stats.norm.pdf(person, person_mean, person_std) # seaborn --> pdf, actual distribution
    plt.plot(person, pdf)
    plt.axvline(x=person_mean, color='r', linestyle='--', linewidth=2)
    plt.text(person_mean + 15, 0.001, f"mu = {round(person_mean)}", color='r')
    plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")

# %%
def show_pdf_actual(item):
    sns.displot(df[item], kde=True, color = "tab:blue", bins=30, alpha=0.2)
    person_max = np.max(df[item])
    person_mean = np.mean(df[item])
    plt.xlabel("Elo Rating")
    plt.ylabel("Density")
    plt.axvline(x=person_mean, color='black', linestyle='--', linewidth=2)
    plt.text(person_max - 45,60, f"mean = {round(person_mean)}", color='black', weight="bold")
    plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")

# %%
show_pdf_actual("0.200")

# %%
show_pdf_actual("0.300")

# %%
show_pdf_actual("0.400")

# %%
show_pdf_actual("0.500")

# %%
show_pdf_actual("0.600")

# %%
show_pdf_actual("0.700")

# %%
show_pdf_actual("0.800")

# %%
show_pdf_actual("0.900")

# %%
show_pdf_actual("0.950")

# %%
show_pdf_actual("0.990")

# %%
show_pdf_actual("1.000")
