# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

import seaborn as sns

# %%
loop = 1000
qn = 300
filename = f"C:/Users/Admin/Desktop/ELO_Rating/Elo-Simulation/src/data/Actual Results C {loop}loop {qn}qn.csv"
df = pd.read_csv(filename)

# %%
df
# Out:
#            0.200        0.300        0.400        0.500        0.600  \
# 0    1013.222347  1013.775170  1044.001447  1091.091858  1140.727677
# 1    1015.300407  1032.458240  1074.901533  1116.999885  1146.018265
# 2    1023.891386  1045.013151  1078.116563  1118.678744  1163.247036
# 3    1027.157948  1048.270842  1078.793056  1122.828054  1164.789584
# 4    1027.784393  1048.341893  1084.519104  1125.786967  1169.105182
# ..           ...          ...          ...          ...          ...
# 995  1307.764871  1385.699849  1393.962569  1479.660103  1548.454841
# 996  1334.583423  1388.499561  1408.706088  1480.826094  1548.638308
# 997  1338.769142  1397.993237  1414.805883  1490.503283  1551.051511
# 998  1341.749311  1402.259108  1436.421556  1492.157497  1594.309599
# 999  1380.236206  1412.601890  1445.400629  1509.515177  1611.545217
#
#            0.700        0.800        0.900        0.950        0.990  \
# 0    1146.073695  1239.500895  1356.196564  1492.886845  1652.956428
# 1    1166.454827  1250.011117  1367.850504  1494.196502  1662.504206
# 2    1188.402305  1253.333705  1383.636500  1510.387894  1663.165425
# 3    1194.850378  1273.276883  1385.634058  1523.052630  1669.508732
# 4    1200.841638  1285.125160  1403.629054  1529.571426  1670.612339
# ..           ...          ...          ...          ...          ...
# 995  1653.977270  1725.980382  1835.829016  1869.773373  1884.646363
# 996  1659.277521  1734.740540  1836.628752  1875.778198  1886.027113
# 997  1666.932072  1737.841271  1837.427721  1877.701391  1887.010303
# 998  1675.761585  1751.209683  1838.995254  1885.958385  1887.160046
# 999  1676.137154  1813.469507  1845.638218  1892.295913  1892.343657
#
#            1.000
# 0    1800.000000
# 1    1800.000000
# 2    1800.000000
# 3    1800.000000
# 4    1800.000000
# ..           ...
# 995  1886.093692
# 996  1886.832482
# 997  1887.377710
# 998  1887.390997
# 999  1895.150223
#
# [1000 rows x 11 columns]

# %%
acc03 = df["0.300"]
acc03
# Out:
# 0      1013.775170
# 1      1032.458240
# 2      1045.013151
# 3      1048.270842
# 4      1048.341893
#           ...
# 995    1385.699849
# 996    1388.499561
# 997    1397.993237
# 998    1402.259108
# 999    1412.601890
# Name: 0.300, Length: 1000, dtype: float64

# %%
item = "0.200"
sns.displot(df[item], kde=True, color = "tab:blue", bins=30, alpha=0.2)
person_mean = np.mean(df[item])
plt.xlabel("Elo Rating")
plt.ylabel("Density")
plt.axvline(x=person_mean, color='black', linestyle='--', linewidth=2)
plt.text(person_mean + 30,80, f"mean = {round(person_mean)}", color='black', weight="bold")
plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")
# Out:
# Text(0.5, 1.0, 'Elo Rating Distribution for C with accuracy = 0.200 (Nloop = 1000, NQn = 300)')

# %%
def show_pdf_normal(item):
    person = df[item]
    person_mean = np.mean(person)
    person_std = np.std(person)
    pdf = stats.norm.pdf(person, person_mean, person_std) # seaborn --> pdf, actual distribution
    plt.plot(person, pdf)
    plt.axvline(x=person_mean, color='r', linestyle='--', linewidth=2)
    plt.text(person_mean + 15, 0.001, f"mu = {round(person_mean)}", color='r')
    plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")

# %%
def show_pdf_actual(item):
    sns.displot(df[item], kde=True, color = "tab:blue", bins=30, alpha=0.2)
    person_max = np.max(df[item])
    person_mean = np.mean(df[item])
    plt.xlabel("Elo Rating")
    plt.ylabel("Density")
    plt.axvline(x=person_mean, color='black', linestyle='--', linewidth=2)
    plt.text(person_max - 45,60, f"mean = {round(person_mean)}", color='black', weight="bold")
    plt.title(f"Elo Rating Distribution for C with accuracy = {item} (Nloop = {loop}, NQn = {qn})")

# %%
show_pdf_actual("0.200")

# %%
show_pdf_actual("0.300")

# %%
show_pdf_actual("0.400")

# %%
show_pdf_actual("0.500")

# %%
show_pdf_actual("0.600")

# %%
show_pdf_actual("0.700")

# %%
show_pdf_actual("0.800")

# %%
show_pdf_actual("0.900")

# %%
show_pdf_actual("1.000")
